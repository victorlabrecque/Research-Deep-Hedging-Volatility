# %% [markdown]
# # Master Research - Notes & Ideas
# ___

# %% [markdown]
# ___
# ### Notes

# %% [markdown]
# **Paper to read**
#
# *SANOS*
# - Lognormal mixture dynamics
# - Breeden-Litzenberger: ∂²C/∂K² (market implied density)
# - No arbitrage conditions (Kellerer)
# - De-Americanisation of options
#
#
#
# *DYSANOS*
# - Discrete local volatility
# - Dupire
# - Volatility surface time series analysis
#
# $$
# -
# $$
#
# **Subject to study**
#
# *DYSANOS*
# - Volatility surface time series analysis

# %% [markdown]
# **DYSANOS surface simulation**
# - surface modeling (SANOS)
# - surface fitting (ML-SANOS)
# - Time series analysis (DYSANOS)
# - Time series simulation (Current research)

# %% [markdown]
# ___
# ### Research Idea
#
# - Risk measure in deep hedging for covered call strategy
# - Risk measure in SANOS surface modeling and simulating (DYSANOS)
# - Time series simulation for DYSANOS
# - Generative time series simulation for DYSANOS (conditional VAEs, conditional GANs, for path auto-dependance)
#
# <br>
#
# Deep hedging for option overlay strategy:
#
# - For deep hedging proposed method, use full surface as factor input, only trade few options (for interpretability and realism): few different strikes and maturities
# - Buy deep ITM call options for full exposure to the asset but with current liquidity

# %% [markdown]
# Simulation of the joint spot and option surface:
#
# - Option 1: historica resampling: Filtered Historical Simulation (FHS) extended to a joint state. Resample actual paired shocks (same as the paper on dynamic portfolio management with options):
#     - Spot leg (GARCH): get standardized residuals
#     - Latent leg: get latent state time serie from historical options
#     - Pair them by date: each date has their joint shock
#     - Simulate by resampling
#     - Drawdown: resampling each day separately destroys volatility clustering and short term dependance. Instead resample blocks (e.g. 5 or 10 days blocks)
#     - Keep a parametric mean reversion, to avoid random walk
# - Option 2: Joint parametric distribution (Gaussian copula, fixed correlation matrix)
#     - Spot leg: GARCH standardized residuals, same as option 1
#     - Latent leg: parametric mean-reverting process of latent state series
#     - Advantages: fewer parameter to estimate, can simulate shock outside historical range: useful for stress testing
#     - Drawback: assume fixed symmetric dependence structure: miss asymetry, tails co-dependence (leverage effect)
# - Option 3: Mix of both, simulate option surfaces from a weight between Gaussian innovation and historical resampling, then simulate the spot.

# %% [markdown]
# ___
# ___
# ### Following Steps

# %% [markdown]
# **General**
# - Get data to implement full SANOS and train DYSANOS
#
# **Potential Goals**
# - Use deep hedging and generative option surface for covered calls/puts investment strategies
# - Improve time series model in DYSANOS (standard time series model, conditional generative AI model)
#
#
# **Fall 2026**
#
# - Improve current deep hedging framework with Reinforcement Learning course at Concordia
# - Add deep hedging test case under different models (Heston, GARCH, ...) with UdeM course
# - Read missing parts of the theory of SANOS and DYSANOS (paper mentionned in the files)
# - Read other option surfaces fitting (parametric, convex optimization, etc.) and generation (papers mentionned in bibliography of DYSANOS, etc.)
#
# **Winter 2027**
# - Improve optimization and other with Convex Optimization course at McGill
# - Improve numerical procedure, finite difference methods with Numerical Analysis II course at Concordia
# - Possibly prepare for MITAC / Internship in Summer 2027
